# %% [markdown]
# # Your First Vector RAG Application: Cat Health Assistant
#
# In this notebook, we will build a dense vector retrieval application using **LangChain v1**, **OpenAI embeddings**, and **Qdrant** as an in-memory vector database.
#
# The goal is to understand the core RAG loop:
#
# 1. Load a cat health guideline PDF
# 2. Split it into smaller chunks
# 3. Embed those chunks
# 4. Store the embeddings in Qdrant
# 5. Retrieve relevant chunks for a question
# 6. Generate an answer grounded in the retrieved context
#
# > Note: This notebook expects Python 3.12 and uses uv for dependency management.
#
# > Note: This is a vector RAG lesson, not a veterinary care tool. The assistant should answer from the PDF and point users to a veterinarian for diagnosis, treatment, medication, or urgent care decisions.

# %% [markdown]
# ## Table of Contents
#
# - Task 1: Environment Setup
# - Task 2: Embedding Similarity Primer
# - Task 3: Documents - Loading the Cat Health Guideline PDF
# - Task 4: Chunking the Documents
# - Task 5: Embeddings and Qdrant
# - Task 6: Retrieval with Scores
# - Task 7: Retrieval Augmented Generation
# - Activity: Tune Retrieval Quality

# %% [markdown]
# ## Task 1: Environment Setup
#
# From the `01_Dense_Vector_Retrieval` folder, install dependencies with uv:
#
# ```bash
# uv sync
# ```
#
# Then open this notebook in Cursor or VS Code and select the Python/Jupyter environment created by uv.

# %% [markdown]
# ### Imports
#
# LangChain v1 separates integrations into partner packages. We will use:
#
# - `langchain_community` for PDF loading
# - `langchain_text_splitters` for chunking
# - `langchain_openai` for chat and embedding models
# - `langchain_qdrant` for the Qdrant vector store

# %%
from pathlib import Path
from math import sqrt
from getpass import getpass
import os

from langchain_community.document_loaders import PyPDFLoader
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_qdrant import QdrantVectorStore
from langchain_text_splitters import RecursiveCharacterTextSplitter
# Out:
# /var/folders/6y/dfhtjwgj12xftndfzdj06vqh0000gn/T/ipykernel_2331/4147450701.py:6: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader

# %% [markdown]
# ### OpenAI API Key
#
# The chat model and embedding model both use OpenAI. If `OPENAI_API_KEY` is not already set in your environment, this cell will ask for it securely.

# %%
if not os.environ.get("OPENAI_API_KEY"):
    os.environ["OPENAI_API_KEY"] = getpass("OpenAI API Key: ")

# %% [markdown]
# ## Task 2: Embedding Similarity Primer
#
# Before we load a full PDF, let's make dense vector retrieval less mysterious.
#
# An embedding model turns text into a list of numbers. Texts with related meaning should land closer together in that vector space.
#
# A common way to score closeness is **cosine similarity**:
#
# ```text
# cosine_similarity(a, b) = dot_product(a, b) / (length(a) * length(b))
# ```
#
# The intuition: if two vectors point in a similar direction, their cosine similarity is higher. Vector databases like Qdrant use this same idea, but at a much larger scale.

# %%
embedding_model = "text-embedding-3-small"
embeddings = OpenAIEmbeddings(model=embedding_model)

example_texts = [
    "king",
    "queen",
    "banana",
    "cat",
    "veterinarian",
    "cat health guidelines",
]

example_vectors = dict(zip(example_texts, embeddings.embed_documents(example_texts)))


def cosine_similarity(vector_a: list[float], vector_b: list[float]) -> float:
    dot_product = sum(a * b for a, b in zip(vector_a, vector_b))
    length_a = sqrt(sum(a * a for a in vector_a))
    length_b = sqrt(sum(b * b for b in vector_b))
    return dot_product / (length_a * length_b)


comparison_pairs = [
    ("king", "queen"),
    ("king", "banana"),
    ("cat", "veterinarian"),
    ("cat", "cat health guidelines"),
]

for left, right in comparison_pairs:
    score = cosine_similarity(example_vectors[left], example_vectors[right])
    print(f"{left:>22} <> {right:<22} score={score:.3f}")
# Out:
#                   king <> queen                  score=0.591
#                   king <> banana                 score=0.310
#                    cat <> veterinarian           score=0.356
#                    cat <> cat health guidelines  score=0.496

# %% [markdown]
# A few important notes:
#
# - The score is useful for ranking, not as an absolute truth about meaning.
# - Different embedding models can produce different scores.
# - In RAG, we embed each document chunk once, then embed the user's query and search for the nearest chunk vectors.
#
# That is the retrieval part of RAG.

# %% [markdown]
# ## Task 3: Documents
#
# LangChain represents loaded text as `Document` objects. A `Document` has:
#
# - `page_content`: the text
# - `metadata`: information such as source file and page number
#
# We will load one `Document` per PDF page, then split those pages into smaller chunks.

# %% [markdown]
# ### Course PDF
#
# This notebook uses the bundled cat health guideline PDF at:
#
# ```text
# 01_Dense_Vector_Retrieval/data/cat_health_guidelines.pdf
# ```
#
# The next cell checks that the course material is present before we start loading pages.

# %%
pdf_path = Path("data/cat_health_guidelines.pdf")

if not pdf_path.exists():
    raise FileNotFoundError(
        f"Expected the cat health guideline PDF at: {pdf_path.resolve()}\n"
        "The bundled course PDF is missing from this copy of the materials."
    )

# %% [markdown]
# ### Load the PDF
#
# `PyPDFLoader` extracts text from text-based PDFs. If the PDF is scanned images, this loader may return little or no text, and OCR would be needed.

# %%
loader = PyPDFLoader(str(pdf_path))
pages = loader.load()

for page in pages:
    page.metadata["source"] = pdf_path.name
    page.metadata["document_type"] = "cat_health_guideline"

pages = [page for page in pages if page.page_content.strip()]

if not pages:
    raise ValueError(
        "The PDF loaded, but no extractable text was found. "
        "This usually means the PDF is scanned and needs OCR first."
    )

print(f"Loaded {len(pages)} text-containing PDF pages.")
# Out:
# Loaded 22 text-containing PDF pages.

# %%
print(pages[0].page_content[:750])
print("\nMetadata:", pages[0].metadata)
# Out:
# VETERINARY PRACTICE GUIDELINES
# 2021 AAHA/AAFP Feline Life Stage Guidelines*
# Jessica Quimby, DVM, PhD, DACVIM y, Shannon Gowland, DVM, DABVP y, Hazel C. Carney, DVM, MS, DABVP,
# Theresa DePorter, DVM, MRCVS, DACVB, DECAWBM, Paula Plummer, LVT, VTS (ECC, SAIM), Jodi Westropp,
# DVM, PhD, DACVIM
# ABSTRACT
# The guidelines, authored by a Task Force ofexperts in feline clinical medicine, are an update and extension of the AAFP–AAHA
# Feline Life Stage Guidelines published in 2010. The guidelines are published simultaneously in theJournal of Feline Medicine and
# Surgery(volume 23, issue 3, pages 211–233, DOI: 10.1177/1098612X21993657) and theJournal of the American Animal Hospital
# Association(volume 57, issue 2, pages 51–72, DOI: 10.5326/JAAHA-MS-7189). A
#
# Metadata: {'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 0, 'page_label': '1', 'document_type': 'cat_health_guideline'}

# %% [markdown]
# #### ❓Question #1
#
# Why is metadata important for a RAG application?
#
# ##### ✅ Answer:
#
# Metadata in RAG applications provide additional information about the data e.g author, date, topic, category etc. This helps to categorize the documents. Metadata enable pre-filtering/filtering and enhance search relevance when stored alongside vector embeddings in vector database. Pre-filtering narrows the search space so your limited k slots aren't consumed by chunks that are similar but not relevant.
#
# RAG in general uses vector similarity which allows to rank data by sematic closeness. Metadata add extra structured deterministric control into probabilistic process. Effective metadata implementation in RAG systems enhances document retrieval accuracy. Consistent metadata tagging across all data entries is crucial for uniform retrieval processes.

# %% [markdown]
# ## Task 4: Chunking the Documents
#
# A full PDF page can be too large or too mixed-topic for high-quality retrieval. We split pages into overlapping chunks so each chunk has enough local context but is still focused.
#
# Here we will start with chunks of 1,000 characters and 200 characters of overlap. The chunk size controls how much text each vector represents; the overlap keeps nearby context from being lost at chunk boundaries.
#
# `RecursiveCharacterTextSplitter` tries to split on natural boundaries first, such as paragraphs and line breaks, before falling back to smaller separators.

# %%
chunk_size = 1000
chunk_overlap = 200

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=chunk_size,
    chunk_overlap=chunk_overlap,
    add_start_index=True,
)

splits = text_splitter.split_documents(pages)

print(f"Split {len(pages)} pages into {len(splits)} chunks.")
print(f"Chunk size: {chunk_size} characters")
print(f"Chunk overlap: {chunk_overlap} characters")
# Out:
# Split 22 pages into 135 chunks.
# Chunk size: 1000 characters
# Chunk overlap: 200 characters

# %%
sample_chunk = splits[0]
print(sample_chunk.page_content[:750])
print("\nMetadata:", sample_chunk.metadata)
# Out:
# VETERINARY PRACTICE GUIDELINES
# 2021 AAHA/AAFP Feline Life Stage Guidelines*
# Jessica Quimby, DVM, PhD, DACVIM y, Shannon Gowland, DVM, DABVP y, Hazel C. Carney, DVM, MS, DABVP,
# Theresa DePorter, DVM, MRCVS, DACVB, DECAWBM, Paula Plummer, LVT, VTS (ECC, SAIM), Jodi Westropp,
# DVM, PhD, DACVIM
# ABSTRACT
# The guidelines, authored by a Task Force ofexperts in feline clinical medicine, are an update and extension of the AAFP–AAHA
# Feline Life Stage Guidelines published in 2010. The guidelines are published simultaneously in theJournal of Feline Medicine and
# Surgery(volume 23, issue 3, pages 211–233, DOI: 10.1177/1098612X21993657) and theJournal of the American Animal Hospital
# Association(volume 57, issue 2, pages 51–72, DOI: 10.5326/JAAHA-MS-7189). A
#
# Metadata: {'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 0, 'page_label': '1', 'document_type': 'cat_health_guideline', 'start_index': 0}

# %% [markdown]
# #### ❓Question #2
#
# What tradeoff do we make when choosing chunk size and chunk overlap?
#
# ##### ✅ Answer:
# The main tradeoff when choosing chunk size in a RAG system is between retrieval precision and context completeness.
#
# Smaller chunks usually produce more focused embeddings because each vector represents a narrower idea. This allows the similarity matching to be more precise. However, if chunks are too small, the information needed to answer a question may be split across multiple chunks. This may cause the retrieved context to be incomplete. On the other hand large chunks give you more self-contained context, which is useful when an answer needs to be reasoned over a longer passage. The drawbag of the larger chunk size is that one chunk can comprise server topics which results in weaker matching to any single one. As a result this hurt the retrieval precision. Moreover, large chunks also inject more irrelevant text into the LLM context (wasting tokens and risking the "lost in the middle" effect) and let fewer chunks fit overall, reducing corpus coverage. Embedding models have an optimal input length that sits below their hard limit, so bigger chunks don't just risk dilution — they can also weaken the embedding itself.
#
# Overlapping refers to the one chunk will share part of the text with another adjacent chunk. Overlap helps mitigate the loss of important context at chunk boundaries. If you have large document that includes complex and interrelated ideas, a single concept might get split across two chunks, leaving neither one complete. By letting consecutive chunks share some text at their edges, overlap ensures that an idea spanning a boundary still appears intact in at least one chunk, so it can be retrieved and understood as a whole. The cost of the overlap is redundant retrieval, increases token costs as well as wastes context window.
#
# So the size choice is essentially a precision-vs-completeness tradeoff, and the best way to ease it is to chunk on natural boundaries (like markdown headers or sections) assuring splits fall where ideas actually end.
#
#
# Use the [Chunk Visualizer](https://chunkviz.up.railway.app/) to experiment with different chunk sizes and overlaps and see how the text boundaries change.

# %% [markdown]
# ## Task 5: Embeddings and Qdrant
#
# Now we apply the same embedding idea to every chunk from the PDF. Qdrant stores those vectors and lets us search for chunks that are close to a query in embedding space.
#
# We already created an OpenAI embedding model in the primer above. The Qdrant collection name is just a label for the set of vectors we are creating.
#
# For this notebook, Qdrant runs in memory with `location=":memory:"`. That means no Docker, no Qdrant Cloud account, and no persistence after the notebook kernel stops.

# %%
collection_name = "cat_health_guidelines"

vector_store = QdrantVectorStore.from_documents(
    documents=splits,
    embedding=embeddings,
    location=":memory:",
    collection_name=collection_name,
    force_recreate=True,
)

print(f"Embedded chunks with: {embedding_model}")
print(f"Built in-memory Qdrant collection: {collection_name}")
# Out:
# Embedded chunks with: text-embedding-3-small
# Built in-memory Qdrant collection: cat_health_guidelines

# %% [markdown]
# ## Task 6: Retrieval with Scores
#
# Before we generate answers, we should inspect retrieval directly. If retrieval returns poor context, the final answer will usually be poor too.
#
# The value `k` controls how many chunks the retriever returns. A larger `k` gives the model more context, but it can also add noise. We will start with `k = 4` and tune it later.
#
# Qdrant can return both the matching `Document` and a similarity score. This is the same ranking idea we saw with `king`, `queen`, and `cat`, now applied to PDF chunks.

# %%
def display_retrieval_results(query: str, k: int) -> list[tuple]:
    """Retrieve chunks and print a compact view of the results."""
    results = vector_store.similarity_search_with_score(query, k=k)

    for index, (doc, score) in enumerate(results, start=1):
        page = doc.metadata.get("page")
        page_display = page + 1 if isinstance(page, int) else "unknown"
        start_index = doc.metadata.get("start_index", "unknown")
        preview = doc.page_content[:350].replace("\n", " ")

        print(f"Source {index} | score={score:.3f} | page={page_display} | start_index={start_index}")
        print(preview)
        print("-" * 80)

    return results

# %%
retrieval_k = 4
retrieval_query = "What signs suggest that a cat should be seen by a veterinarian?"
retrieved_results = display_retrieval_results(retrieval_query, k=retrieval_k)
# Out:
# Source 1 | score=0.584 | page=8 | start_index=0
# Detecting signs of pain or anxiety and evaluation of quality of life are most commonly of concern in the mature adult or senior cat but may be relevant at any life stage. During the physical examination, particular focus is on pain assessment and abdominal and thyroid palpation. A detailed mus- culoskeletal examination to detect signs of osteoarthr
# --------------------------------------------------------------------------------
# Source 2 | score=0.571 | page=7 | start_index=2384
# Asking speci ﬁc questions concerning whether vomiting, vom- iting hairballs, or diarrhea is occurring, and the frequency of each, is recommended as some clients may consider vomiting or vomiting hairballs to be normal for their cat. Additionally, discuss the im- portance of monitoring weight, and ask about any chronic enter- opathy or gastrointesti
# --------------------------------------------------------------------------------
# Source 3 | score=0.565 | page=7 | start_index=3237
# increased nocturnal activity and vocalization as well as changes in the cat ’s normal habits or activity. These may indicate cognitive dysfunction, disease-reduced mobility, pain, or reduced vision. TABLE 3 Diseases and Conditions That Require Particular Focus During Examination, by Life Stage 2021 AAHA/AAFP Feline Life Stage Guidelines JAAHA.ORG 5
# --------------------------------------------------------------------------------
# Source 4 | score=0.554 | page=7 | start_index=820
# 24 Changes in demeanor, activity level, and behavior are additionally key to note and trend over time. Asking speci ﬁc questions as to whether the kitten is displaying any unwanted behaviors, counselling clients on normal kitten be- havior, and giving advice on positive methods to modify unwanted behavior are critical discussion points at this stag
# --------------------------------------------------------------------------------

# %% [markdown]
# #### ❓Question #3
#
# What does a similarity score help you understand, and what does it not prove by itself?
#
# ##### ✅ Answer:
#
# A similarity score quantifies how closely a piece of retrieved data matches the input query. It is useful for ranking chunks and deciding which piece of context is most likely to be relevant. The high score means indicate a stronger match - the query and chunk were deemed to be close in semantic meaning. It does not assure that the retrieved text contains the answer, is complete or usefull. A high score can still retrieve text that is related but not complete enough to answer the actual question. Similarity scores are useful for ranking but they should be followed by validation step.

# %% [markdown]
# ## Task 7: Retrieval Augmented Generation
#
# Now we combine retrieval with generation. We will use a two-step RAG pattern:
#
# 1. Retrieve relevant chunks from Qdrant
# 2. Put those chunks into the prompt and ask the model to answer from the context
#
# This is intentionally simpler than an agent. We always retrieve before answering, which makes the vector retrieval mechanics easy to inspect.
#
# For generation, we will use `gpt-5.4-mini`.

# %%
chat_model = "gpt-5.4-mini"
llm = ChatOpenAI(model=chat_model)

RAG_SYSTEM_PROMPT = """You are a cat health guideline assistant in a vector RAG lesson.

Use only the provided context to answer the user's question.
If the context does not contain enough information, say: "I don't have enough information in the provided cat health guideline PDF to answer that."

Cite the retrieved sources inline using labels like [Source 1] or [Source 2].
Do not diagnose, prescribe medication, or replace a veterinarian.
For diagnosis, treatment decisions, medication questions, or urgent symptoms, recommend contacting a veterinarian.
Keep the answer concise and practical."""

RAG_USER_PROMPT = """Context:
{context}

Question: {question}

Answer from the context above."""

rag_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", RAG_SYSTEM_PROMPT),
        ("human", RAG_USER_PROMPT),
    ]
)

rag_chain = rag_prompt | llm | StrOutputParser()

# %%
def format_context(scored_docs: list[tuple]) -> str:
    """Convert retrieved documents into a source-labeled context string."""
    formatted_chunks = []

    for index, (doc, score) in enumerate(scored_docs, start=1):
        page = doc.metadata.get("page")
        page_display = page + 1 if isinstance(page, int) else "unknown"
        source = doc.metadata.get("source", "unknown source")

        formatted_chunks.append(
            f"[Source {index}] {source}, page {page_display}, score {score:.3f}\n"
            f"{doc.page_content}"
        )

    return "\n\n".join(formatted_chunks)


def answer_question(question: str, k: int) -> dict:
    """Run retrieve-then-generate and return the answer plus source metadata."""
    scored_docs = vector_store.similarity_search_with_score(question, k=k)
    context = format_context(scored_docs)
    answer = rag_chain.invoke({"context": context, "question": question})

    sources = []
    for index, (doc, score) in enumerate(scored_docs, start=1):
        page = doc.metadata.get("page")
        sources.append(
            {
                "source_label": f"Source {index}",
                "file": doc.metadata.get("source"),
                "page": page + 1 if isinstance(page, int) else None,
                "start_index": doc.metadata.get("start_index"),
                "score": score,
            }
        )

    return {
        "question": question,
        "answer": answer,
        "sources": sources,
        "context": scored_docs,
    }

# %% [markdown]
# Before calling the model, inspect the formatted context. This is the exact text that will be inserted into the RAG prompt.

# %%
example_context = format_context(retrieved_results[:2])
print(example_context[:2000])
# Out:
# [Source 1] cat_health_guidelines.pdf, page 8, score 0.584
# Detecting signs of pain or anxiety and evaluation of quality of life
# are most commonly of concern in the mature adult or senior cat but
# may be relevant at any life stage.
# During the physical examination, particular focus is on pain
# assessment and abdominal and thyroid palpation. A detailed mus-
# culoskeletal examination to detect signs of osteoarthritis is critical as
# this condition is one of the most signi ﬁcant and underdiagnosed
# diseases in cats.
# 23,28 A fundic examination is key to detecting signs of
# ophthalmic disease or hypertension. 29 Practices should employ a
# validated pain assessment scale or tool to diagnose, monitor, and
# assist in the evaluation of patients for subtle signs of pain.
# 30
# Changes in grooming habits, particularly increased grooming,
# may signal a dermatologic issue such as atopy, food allergy, an
# immune-mediated skin condition, infectious or parasitic disease,
# endocrine condition, or paraneoplastic syndrome.
# 31 Reduced grooming
#
# [Source 2] cat_health_guidelines.pdf, page 7, score 0.571
# Asking speci ﬁc questions concerning whether vomiting, vom-
# iting hairballs, or diarrhea is occurring, and the frequency of each, is
# recommended as some clients may consider vomiting or vomiting
# hairballs to be normal for their cat. Additionally, discuss the im-
# portance of monitoring weight, and ask about any chronic enter-
# opathy or gastrointestinal (GI) signs that could indicate early stages of
# disease.
# Mature Adult and Senior Cats
# The medical history and examination of mature adult and senior cats
# will be focused on early detection of disease. Adult and senior cats are
# often diagnosed with comorbidities. Speci ﬁc questions regarding
# changes in appetite, occurrence of polyuria and polydipsia, vomiting,
# vomiting hairballs, or diarrhea are of key importance to guide di-
# agnostic testing. Discussion should also be held with the client about
# increased nocturnal activity and vocalization as well as changes

# %%
answer_k = 4

result = answer_question(
    "What are signs that my cat may need veterinary attention?",
    k=answer_k,
)

print(result["answer"])
print("\nSources:")
for source in result["sources"]:
    print(source)
# Out:
# Signs that your cat may need veterinary attention can include changes in grooming habits, especially increased or reduced grooming, which may signal skin disease, illness, bladder pain, joint pain, or reduced mobility [Source 1][Source 2]. Other signs include vomiting, vomiting hairballs, diarrhea, changes in appetite, increased thirst or urination, increased nocturnal activity, vocalization, or changes in normal habits or activity [Source 3].
#
# Behavioral or stress signs can also matter: cowering, crouching, crawling, muscular tension, freezing, hiding, frantic fleeing, flattened or rotated ears, dilated pupils, forward whiskers, and hissing, yowling, growling, or screaming [Source 4].
#
# If you notice these signs, contact a veterinarian for an evaluation.
#
# Sources:
# {'source_label': 'Source 1', 'file': 'cat_health_guidelines.pdf', 'page': 8, 'start_index': 0, 'score': 0.596214318138008}
# {'source_label': 'Source 2', 'file': 'cat_health_guidelines.pdf', 'page': 8, 'start_index': 767, 'score': 0.568389233136958}
# {'source_label': 'Source 3', 'file': 'cat_health_guidelines.pdf', 'page': 7, 'start_index': 2384, 'score': 0.5574492823720467}
# {'source_label': 'Source 4', 'file': 'cat_health_guidelines.pdf', 'page': 8, 'start_index': 3963, 'score': 0.5537978394436083}

# %% [markdown]
# ### Vibe Check Queries
#
# Run a few questions that should be answerable from a cat health guideline PDF. Then run one question that may not be answerable and confirm the assistant says it does not have enough information.

# %%
vibe_check_questions = [
    "What preventive care is recommended for cats?",
    "What symptoms should make me call a veterinarian?",
    "What should I know about feeding a healthy adult cat?",
    "Can my cat help me file my taxes?",
]

for question in vibe_check_questions:
    print("Question:", question)
    print(answer_question(question, k=answer_k)["answer"])
    print("=" * 100)
# Out:
# Question: What preventive care is recommended for cats?
# The guidelines recommend **individualized preventive care based on a cat’s risk and life stage**, with a **minimum of annual veterinary examinations for all cats** and more frequent visits as needed [Source 4]. Preventive strategies may include **routine broad-spectrum parasite control** for most pet cats, especially when risk is higher due to outdoor lifestyle, travel, boarding, or groomer visits [Source 1]. They also note that **cats in the same household may need synchronized treatment for parasites** to reduce spread [Source 1].
# ====================================================================================================
# Question: What symptoms should make me call a veterinarian?
# According to the guideline, you should call a veterinarian if your cat has changes in appetite, polyuria/polydipsia, vomiting, vomiting hairballs, diarrhea, increased nocturnal activity or vocalization, or changes in normal habits/activity [Source 1][Source 3]. The guideline also notes that changes in jumping or climbing in senior cats can be important to mention [Source 2].
#
# If the symptoms seem urgent or are worsening, contact a veterinarian.
# ====================================================================================================
# Question: What should I know about feeding a healthy adult cat?
# For a healthy adult cat, feeding should be based on the cat’s age, body condition score (BCS), muscle condition score (MCS), activity level, neuter status, and overall health [Source 2][Source 3].
#
# A good starting point for energy needs is:
# - **RER = 30 × body weight in kg + 70**
# - For **young, healthy adults**, **DER = RER × 1** [Source 1]
#
# Food intake can then be adjusted by comparing the cat’s DER with the **caloric density** of the food [Source 1].
#
# A few practical points:
# - Cats should be fed **diets labeled with an Association of American Feed Control Officials statement of nutritional adequacy** to help avoid nutrient deficiencies [Source 2].
# - The amount fed should be adjusted to **maintain ideal body condition** [Source 3].
# - If changing diets, a **gradual transition over 7–10 days** is recommended [Source 4].
#
# If you’re trying to figure out the right amount for a specific cat, a veterinarian can help assess BCS and make a feeding plan.
# ====================================================================================================
# Question: Can my cat help me file my taxes?
# I don't have enough information in the provided cat health guideline PDF to answer that.
# ====================================================================================================

# %%
display_retrieval_results("Can my cat help me file my taxes?", k=answer_k)
# Out:
# Source 1 | score=0.380 | page=10 | start_index=1637
# Young Adult Cats Y oung adult cats do not require as frequent routine medical care as kittens, so it is integral to educate the client about why regular healthcare examinations remain so important. Routine examinations can help identify behavioral changes or medical concerns that may affect a cat ’s health long before they become signi ﬁcant, painf
# --------------------------------------------------------------------------------
# Source 2 | score=0.379 | page=20 | start_index=2443
# silvestris catus) kept in the home. Appl Anim Behav Sci 2005;93:97–109. 62. Clancy EA, Moore AS, Bertone ER. Evaluation of cat and owner characteristics and their relationships to outdoor access of owned cats. J Am V et Med Assoc 2003;222:1541–5. 63. Neville PF. An ethical viewpoint: the role of veterinarians and behaviourists in ensuring good husb
# --------------------------------------------------------------------------------
# Source 3 | score=0.367 | page=19 | start_index=3249
# free-roaming cats. Top Companion Anim Med 2017;32:91–5. 22. Whyte A, Lacasta S, Whyte J, et al. T ooth resorption in Spanish do- mestic cats: preliminary data. Top Companion Anim Med 2020;38: 100369. DOI: 10.1016/j.tcam.2019.100369. 23. Bennett D, Arifﬁn SMZ, Johnston P . Osteoarthritis in the cat: how common is it and how easy to recognise? J Feli
# --------------------------------------------------------------------------------
# Source 4 | score=0.365 | page=8 | start_index=3153
# 36 Cats are popular pets that reside in 25% of U.S. households with a mean of 1.8 cats per household, 39 a demographic statistic that highlights the importance of understanding often complex feline interrelationships. Many people believe their cats get along, whereas in reality, they may display overt aggression (hissing or swatting) or become pass
# --------------------------------------------------------------------------------
# [(Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 9, 'page_label': '10', 'document_type': 'cat_health_guideline', 'start_index': 1637, '_id': 'f1dfece0cb904f689b9407f80951a725', '_collection_name': 'cat_health_guidelines'}, page_content='Young Adult Cats\nY oung adult cats do not require as frequent routine medical care as\nkittens, so it is integral to educate the client about why regular\nhealthcare examinations remain so important. Routine examinations\ncan help identify behavioral changes or medical concerns that may\naffect a cat ’s health long before they become signi ﬁcant, painful, or\nmore costly to treat. Clients should be educated about the subtle\nchanges in behavior and day-to-day life of the cat that may possibly\nbe signi ﬁcant. Encouraging owners to routinely record behaviors in\na journal and/or with photos and video will provide a basis for\ndocumenting any such changes. Simply asking the client, “Is your\ncat happy? ” may help them think about their cat ’s welfare.\nUrine marking is most often displayed by intact male cats,\nalthough one study reported that about 10% of sterilized cats marked\ntheir territory with urine.\n54 The onset of this behavior can coincide'),
#   0.37977624587457626),
#  (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 19, 'page_label': '20', 'document_type': 'cat_health_guideline', 'start_index': 2443, '_id': 'a4a98fceb76d4fef8551387009824b37', '_collection_name': 'cat_health_guidelines'}, page_content='silvestris catus) kept in the home. Appl Anim Behav Sci 2005;93:97–109.\n62. Clancy EA, Moore AS, Bertone ER. Evaluation of cat and owner\ncharacteristics and their relationships to outdoor access of owned cats. J\nAm V et Med Assoc 2003;222:1541–5.\n63. Neville PF. An ethical viewpoint: the role of veterinarians and behaviourists\nin ensuring good husbandry for cats. J Feline Med Surg 2004;6:43–8.\n64. T oribio JLM, Norris JM, White JD, et al. Demographics and husbandry\nof pet cats living in Sydney, Australia: results of cross-sectional survey of\npet ownership. J Feline Med Surg 2009;11:449–61.\n65. Rochlitz I. The welfare of cats . Dordrecht (Netherlands): Springer; 2005.\n66. Clarke DL, Wrigglesworth D, Holmes K, et al. Using environmental\nenrichment and feeding enrichment to facilitate feline weight loss. J\nAnim Physiol Anim Nutr (Berl) 2005;89:427. DOI: 10.1111/j.1439-\n0396.2005.00611_1.x.\n67. AAFP Position Statement: Positive reinforcement for cats. 2012. Available at:'),
#   0.379240274578698),
#  (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 18, 'page_label': '19', 'document_type': 'cat_health_guideline', 'start_index': 3249, '_id': 'ad25723075a741029ca3f918e64ded8e', '_collection_name': 'cat_health_guidelines'}, page_content='free-roaming cats. Top Companion Anim Med 2017;32:91–5.\n22. Whyte A, Lacasta S, Whyte J, et al. T ooth resorption in Spanish do-\nmestic cats: preliminary data. Top Companion Anim Med 2020;38:\n100369. DOI: 10.1016/j.tcam.2019.100369.\n23. Bennett D, Arifﬁn SMZ, Johnston P . Osteoarthritis in the cat: how common\nis it and how easy to recognise? J Feline Med Surg 2012;14:65–75.\n24. AAHA. 2010 AAHA nutritional assessment guidelines for dogs and cats.\nAvailable at: aaha.org/aaha-guidelines/nutritional-assessment-conﬁguration/\nnutritional-assessment-introduction/.\n25. Purina. Fecal Scoring Chart. Available at: https://www.proplanveterinarydiets.ca/\nwp-content/uploads/2018/05/180107_PPPVD-Fecal-Scoring-Chart-UP-\nDATE-EN-FINAL.pdf.\n26. Royal Canin. Fecal Scoring System for Cats. 2020. Available at: https://\nroyalcanin-us.my.salesforce.com/sfc/p/j0000001rD9A/a/5b000000QMW8/\n8FRFiG8lTxRVN0rrLvXHrb9shSxH3cqoC.XA.ltJj2s.\n27. Rozanski E. Feline lower airway disease. In: Little S, ed. August’s con-'),
#   0.36667451707688564),
#  (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 7, 'page_label': '8', 'document_type': 'cat_health_guideline', 'start_index': 3153, '_id': '67cc29d50157428d8df8dd400a92881e', '_collection_name': 'cat_health_guidelines'}, page_content='36\nCats are popular pets that reside in 25% of U.S. households with\na mean of 1.8 cats per household, 39 a demographic statistic that\nhighlights the importance of understanding often complex feline\ninterrelationships. Many people believe their cats get along, whereas\nin reality, they may display overt aggression (hissing or swatting) or\nbecome passively avoidant. In contrast, af ﬁliative relationships are\ncharacterized by behaviors such as allogrooming, nose touching, or\nsleeping in close contact.\n40,41\nFeline Communication Signs\nAlthough cats may be distressed, they are stealthy in their ability to\nhide anxiety. A content cat will hold its ears forward, whiskers loose\nor relaxed, muscles soft, and tail loosely wrapped. Practitioners\nshould closely observe feline body language postures for even the\nmost subtle signs of anxiety and tension. Clinical signs of fear or\nstress in cats are displayed through characteristic body postures,'),
#   0.36480933567025337)]

# %% [markdown]
# #### ❓Question #4
#
# For the vibe check queries above, did the retrieved context seem relevant before generation? Why or why not?
#
# ##### ✅ Answer:
#
# For the three health-related queries ("What preventive care is recommended for cats?", "What symptoms should make me call a veterinarian?", "What should I know about feeding a healthy adult cat?"), the retrieved context appeared relevant before generation. The chunks contain relevant infomation for the question e.g symptoms of sickness, early detection of disease, changes in grooming patterns etc. The similarity scores were reasonable. The content aligned with what was being asked.
# For the question "Can my cat help me file my taxes?" the retrieval returned 4 chunks about routine vet care, academic references, tooth resorption, and cat household demographics (see in cell above). None of the chunks contain relevant information. Similarity scores of those chunks are quite low between 0.365-0.380. That confirms the retrieved context was not relevant.

# %% [markdown]
# ## 🏗️ Activity: Tune Retrieval Quality
#
# Improve retrieval quality by changing one or more of these values:
#
# - The chunk size
# - The chunk overlap
# - The retrieval `k`
# - The wording of the retrieval query
#
# Suggested workflow:
#
# 1. Pick one test question.
# 2. Inspect the retrieved chunks and scores.
# 3. Change one retrieval setting.
# 4. Rebuild the splitter and vector store.
# 5. Compare whether the retrieved chunks became more relevant.
#
# When you are done, write down what changed and whether the final answer improved.

# %%
# new settings
adjusted_chunk_size = 700
adjusted_chunk_overlap = 150
adjusted_k = 5

adjusted_splitter = RecursiveCharacterTextSplitter(
    chunk_size=adjusted_chunk_size,
    chunk_overlap=adjusted_chunk_overlap,
    add_start_index=True,
)

tuned_splits = adjusted_splitter.split_documents(pages)
print(f"Split {len(pages)} pages into {len(tuned_splits)} chunks (was {len(splits)} with chunk_size={chunk_size})")

adjusted_vector_store = QdrantVectorStore.from_documents(
    documents=tuned_splits,
    embedding=embeddings,
    location=":memory:",
    collection_name="cat_health_tuned",
    force_recreate=True,
)

# Compare query with original vs new parameters

#Original
test_query = "What are signs that my cat may need veterinary attention?"

print("Initial settings - chunk_size=1000, k=4")
results=display_retrieval_results(test_query, k=retrieval_k)
print(results)

print("----------------------------------------------")

# Adjusted
print("Adjusted Settings - chunk_size=500, k=6")
tuned_results = adjusted_vector_store.similarity_search_with_score(test_query, k=adjusted_k)

for i, (doc, score) in enumerate(tuned_results, start=1):
    page = doc.metadata.get("page")
    page_display = page + 1 if isinstance(page, int) else "unknown"
    preview = doc.page_content[:350].replace("\n", " ")
    print(f"Source {i} | score={score:.3f} | page={page_display}")
    print(preview)
    print("-" * 80)
# Out:
# Split 22 pages into 194 chunks (was 135 with chunk_size=1000)
# Initial settings - chunk_size=1000, k=4
# Source 1 | score=0.596 | page=8 | start_index=0
# Detecting signs of pain or anxiety and evaluation of quality of life are most commonly of concern in the mature adult or senior cat but may be relevant at any life stage. During the physical examination, particular focus is on pain assessment and abdominal and thyroid palpation. A detailed mus- culoskeletal examination to detect signs of osteoarthr
# --------------------------------------------------------------------------------
# Source 2 | score=0.568 | page=8 | start_index=767
# may signal a dermatologic issue such as atopy, food allergy, an immune-mediated skin condition, infectious or parasitic disease, endocrine condition, or paraneoplastic syndrome. 31 Reduced grooming by the cat may also indicate underlying illness, bladder pain, degener- ative joint disease (DJD) pain, or reduced mobility. Behavior and Environmental
# --------------------------------------------------------------------------------
# Source 3 | score=0.557 | page=7 | start_index=2384
# Asking speci ﬁc questions concerning whether vomiting, vom- iting hairballs, or diarrhea is occurring, and the frequency of each, is recommended as some clients may consider vomiting or vomiting hairballs to be normal for their cat. Additionally, discuss the im- portance of monitoring weight, and ask about any chronic enter- opathy or gastrointesti
# --------------------------------------------------------------------------------
# Source 4 | score=0.554 | page=8 | start_index=3963
# most subtle signs of anxiety and tension. Clinical signs of fear or stress in cats are displayed through characteristic body postures, vocalizations, and activity. A cowering (tense, ﬂattened) position where the head is lower than the body may be indicative of stress or fear in cats. A state of distress may also be characterized by crouching, crawl
# --------------------------------------------------------------------------------
# [(Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 7, 'page_label': '8', 'document_type': 'cat_health_guideline', 'start_index': 0, '_id': 'd1840a3abc1d4b938ee93730210940e8', '_collection_name': 'cat_health_guidelines'}, page_content='Detecting signs of pain or anxiety and evaluation of quality of life\nare most commonly of concern in the mature adult or senior cat but\nmay be relevant at any life stage.\nDuring the physical examination, particular focus is on pain\nassessment and abdominal and thyroid palpation. A detailed mus-\nculoskeletal examination to detect signs of osteoarthritis is critical as\nthis condition is one of the most signi ﬁcant and underdiagnosed\ndiseases in cats.\n23,28 A fundic examination is key to detecting signs of\nophthalmic disease or hypertension. 29 Practices should employ a\nvalidated pain assessment scale or tool to diagnose, monitor, and\nassist in the evaluation of patients for subtle signs of pain.\n30\nChanges in grooming habits, particularly increased grooming,\nmay signal a dermatologic issue such as atopy, food allergy, an\nimmune-mediated skin condition, infectious or parasitic disease,\nendocrine condition, or paraneoplastic syndrome.\n31 Reduced grooming'), 0.596214318138008), (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 7, 'page_label': '8', 'document_type': 'cat_health_guideline', 'start_index': 767, '_id': 'd199ce9e829c405991841dc575ce3bd7', '_collection_name': 'cat_health_guidelines'}, page_content='may signal a dermatologic issue such as atopy, food allergy, an\nimmune-mediated skin condition, infectious or parasitic disease,\nendocrine condition, or paraneoplastic syndrome.\n31 Reduced grooming\nby the cat may also indicate underlying illness, bladder pain, degener-\native joint disease (DJD) pain, or reduced mobility.\nBehavior and Environmental Needs\nUnderstanding and Enhancing Behavior by Life Stage\nFeline health and welfare are intricately interrelated at all life stages.\nFrom kitten to senior, an appreciation of the behavioral needs of the\ncat is essential for preventing behavior problems. Problem behaviors\nmay be manifestations of normal feline behaviors, ranging from\nundesirable to pathological misbehaviors. Such problems continue to\nbe a primary reason for relinquishment.\n32 House-soiling (marking or\ntoileting outside the litter box) 33 and aggression toward people,\nhousemate cats, or housemate dogs 34 are commonly reported rea-\nsons for relinquishment.'), 0.568389233136958), (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 6, 'page_label': '7', 'document_type': 'cat_health_guideline', 'start_index': 2384, '_id': '643523994d1d41edbeb9439fdaced6f4', '_collection_name': 'cat_health_guidelines'}, page_content='Asking speci ﬁc questions concerning whether vomiting, vom-\niting hairballs, or diarrhea is occurring, and the frequency of each, is\nrecommended as some clients may consider vomiting or vomiting\nhairballs to be normal for their cat. Additionally, discuss the im-\nportance of monitoring weight, and ask about any chronic enter-\nopathy or gastrointestinal (GI) signs that could indicate early stages of\ndisease.\nMature Adult and Senior Cats\nThe medical h ...
# ----------------------------------------------
# Adjusted Settings - chunk_size=500, k=6
# Source 1 | score=0.613 | page=10
# Senior cats exhibiting new or unusual behavior should be evaluated for medical conditions. 12 Changes in litter box usage may indicate urinary tract disease, constipation, or diabetes but may also be due to reduced musculoskeletal strength, impaired balance, or onset of pain. V ocali- zation, especially nighttime waking, is a common concern and may
# --------------------------------------------------------------------------------
# Source 2 | score=0.563 | page=8
# ophthalmic disease or hypertension. 29 Practices should employ a validated pain assessment scale or tool to diagnose, monitor, and assist in the evaluation of patients for subtle signs of pain. 30 Changes in grooming habits, particularly increased grooming, may signal a dermatologic issue such as atopy, food allergy, an immune-mediated skin conditi
# --------------------------------------------------------------------------------
# Source 3 | score=0.561 | page=8
# Detecting signs of pain or anxiety and evaluation of quality of life are most commonly of concern in the mature adult or senior cat but may be relevant at any life stage. During the physical examination, particular focus is on pain assessment and abdominal and thyroid palpation. A detailed mus- culoskeletal examination to detect signs of osteoarthr
# --------------------------------------------------------------------------------
# Source 4 | score=0.555 | page=8
# V ocalizations, including hissing, yowling, growling, or screaming, may indicate defensiveness. A rapid respiratory rate not associated with disease or exertion may also be observed. The tail may ﬂip or twitch as the cat becomes agitated; the rate and intensity of the tail movement correlates with the cat ’s distress. Other activities and body lang
# --------------------------------------------------------------------------------
# Source 5 | score=0.553 | page=7
# increased nocturnal activity and vocalization as well as changes in the cat ’s normal habits or activity. These may indicate cognitive dysfunction, disease-reduced mobility, pain, or reduced vision. TABLE 3 Diseases and Conditions That Require Particular Focus During Examination, by Life Stage 2021 AAHA/AAFP Feline Life Stage Guidelines JAAHA.ORG 5
# --------------------------------------------------------------------------------

# %% [markdown]
# ### 🏗️ Activity Notes
#
# - Setting changed: chunk_size was changed from 1000 to 700, chunk overlap was increased from 200 to 150, k changed from 4 to 5
# - Before: 135 chunks, top 4 results with scores 0.554–0.596
# - After: 194 chunks, top 5 results with scores 0.553–0.613
#
# - Did retrieval improve? Why or why not?
#
# Let's compare:
#
# Before chunks:
# 1. Pain and anxiety, osteoarthritis, grooming changes  (relevant) 🟩
# 2. Reduced grooming indicating illness/pain (mentioned clear signs) 🟩
# 3. Vomiting, hairballs, diarrhea, appetite changes, polyuria/polydipsia, nocturnal activity (relevant -very concrete symptoms owner would observe) 🟩
# 4. Signs on tension and anxiety (potentially concerning but not necessary concern for the owner that requires vet attention) 🟧
#
# After chunks:
# 1. Litter box changes, nighttime waking - (relevant and not captured in before chunks) 🟩
# 2. Ophthalmic disease, hypertension — (relevant) 🟩
# 3.  Pain and anxiety, osteoarthritis, grooming changes  (relevant) 🟩
# 4. Vocalizations, body language and anxiety  (potentially concerning but not necessary concern for the owner that requires vet attention) 🟧
# 5. nocturnal activity and vocalization (relevant) 🟩
#
# We can conclude that retrieval has improved because of following:
# - 4/5 (80%) relevant results vs 3/4 (75%) before (we could argue that chunks marged in orange are somewhat relevant)
# - got higher scores 0.613 vs 0.596
#
# Smaller chunks (700 vs 1000) create more focused semantic embeddings, so each chunk represents a tighter topic.  Increasing k from 4 to 5 also cast a wider net, capturing more relevant diversity.
